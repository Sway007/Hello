# %% [markdown]
# # Exercise

# %% [markdown]
# * the left graph shows the svm classifier.
# * the right show the details of how the data changes when we use the kernel function

# %%
# %run lab_svm.py

# %% [markdown]
# refs:
# [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/05.07-support-vector-machines.html)
